# %%
import pandas as pd
import numpy as np
from utils.ModelingUtils import *
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, roc_auc_score, roc_curve, auc, make_scorer, accuracy_score, precision_score, f1_score
import joblib

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
data = pd.read_parquet('../data/final_data_to_modeling1105.parquet')
data = make_ml_target_classification(data)[MODEL_FEATURES]

y = data['ML_TARGET'].values
X = data.drop('ML_TARGET', axis=1)

_, _, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

processed_df_train = pd.read_parquet(f'../data/preprocessed_for_modeling/train_data_1205.parquet')
processed_df_test = pd.read_parquet(f'../data/preprocessed_for_modeling/test_data_1205.parquet')

# %%
X_train = processed_df_train.drop('ML_TARGET', axis=1)
X_test = processed_df_test.drop('ML_TARGET', axis=1)

# %%
param_grid = {
    'learning_rate': [0.01, 0.05, 0.1, 0.3],
    'max_depth': [3, 5, 7, 9],
    'min_child_weight': [1, 3, 5, 7],
    'subsample': [0.5, 0.7, 0.9, 1.0],
    'colsample_bytree': [0.5, 0.7, 0.9, 1.0],
    'n_estimators': [100, 200, 300, 400],
    'reg_lambda': [0, 1e-5, 1e-2, 0.1],
    'reg_alpha': [0, 1e-5, 1e-2, 0.1]
}

# %%
model = XGBClassifier(objective='multi:softmax', random_state=123, num_class=4)
precision_scorer = make_scorer(precision_score, average='macro')
f1_scorer = make_scorer(f1_score, average='macro')
cv = RandomizedSearchCV(model, param_distributions=param_grid, scoring=f1_scorer, cv=2, verbose=3, random_state=123, n_iter=50)
cv.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 50 candidates, totalling 100 fits
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.305 total time= 2.1min
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.300 total time= 2.1min
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7;, score=0.435 total time=  55.4s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=0.7;, score=0.426 total time=  49.8s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.376 total time=  52.0s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.372 total time=  51.9s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.9;, score=0.243 total time=  35.2s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0, reg_lambda=0, subsample=0.9;, score=0.241 total time=  38.1s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=7, n_estimators=400, reg_alpha=1e-05, reg_lambda=0.1, subsample=0.5;, score=0.406 total time= 1.9min
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=9, min_child_weight=7, n_estimators=400, reg_alpha=1e-05, reg_lambda=0.1, subsample=0.5;, score=0.400 total time= 2.0min
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.9;, score=0.263 total time=  42.8s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.9;, score=0.266 total time=  37.5s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.9;, score=0.382 total time= 1.2min
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.9;, score=0.380 total time= 1.2min
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, reg_alpha=1e-05, reg_lambda=0, subsample=0.7;, score=0.404 total time=  25.5s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=100, reg_alpha=1e-05, reg_lambda=0, subsample=0.7;, score=0.396 total time=  25.7s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1e-05, reg_lambda=0, subsample=1.0;, score=0.326 total time=  54.9s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=5, n_estimators=200, reg_alpha=1e-05, reg_lambda=0, subsample=1.0;, score=0.319 total time=  56.3s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0.01, subsample=0.9;, score=0.409 total time=  43.8s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0.01, subsample=0.9;, score=0.404 total time=  41.0s
# [CV 1/2] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=1.0;, score=0.344 total time=  29.0s
# [CV 2/2] END colsample_bytree=0.9, learning_rate=0.3, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0.01, subsample=1.0;, score=0.341 total time=  29.9s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7;, score=0.265 total time=  19.3s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.1, reg_lambda=0.01, subsample=0.7;, score=0.265 total time=  18.5s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.9;, score=0.380 total time= 1.9min
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.9;, score=0.372 total time= 1.9min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0.01, reg_lambda=0, subsample=0.7;, score=0.285 total time= 1.1min
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=400, reg_alpha=0.01, reg_lambda=0, subsample=0.7;, score=0.284 total time= 1.1min
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.231 total time=  29.6s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.231 total time=  29.7s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.7;, score=0.301 total time=  46.0s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=200, reg_alpha=0.1, reg_lambda=0, subsample=0.7;, score=0.296 total time=  45.2s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.296 total time=  45.8s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.9;, score=0.290 total time=  41.4s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.236 total time=  14.8s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.231 total time=  14.4s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.7;, score=0.251 total time=  30.8s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=0.01, subsample=0.7;, score=0.250 total time=  29.5s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.249 total time=  19.1s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.248 total time=  18.1s
# [CV 1/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9;, score=0.231 total time=  46.2s
# [CV 2/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=3, min_child_weight=7, n_estimators=300, reg_alpha=0.01, reg_lambda=0.1, subsample=0.9;, score=0.231 total time=  47.4s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.333 total time= 1.5min
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=1, n_estimators=400, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.324 total time= 1.5min
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.231 total time=  25.1s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.231 total time=  26.6s
# [CV 1/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=1e-05, reg_lambda=0.01, subsample=0.7;, score=0.286 total time= 1.6min
# [CV 2/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=9, min_child_weight=3, n_estimators=300, reg_alpha=1e-05, reg_lambda=0.01, subsample=0.7;, score=0.285 total time= 1.5min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=1e-05, reg_lambda=0, subsample=1.0;, score=0.243 total time=  36.9s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=1e-05, reg_lambda=0, subsample=1.0;, score=0.241 total time=  36.8s
# [CV 1/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9;, score=0.260 total time=  51.6s
# [CV 2/2] END colsample_bytree=0.9, learning_rate=0.01, max_depth=7, min_child_weight=7, n_estimators=200, reg_alpha=0, reg_lambda=0.1, subsample=0.9;, score=0.259 total time=  50.2s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7;, score=0.278 total time= 1.9min
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7;, score=0.275 total time= 1.8min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.5;, score=0.414 total time= 1.1min
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.3, max_depth=7, min_child_weight=3, n_estimators=300, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.5;, score=0.413 total time= 1.1min
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.383 total time=  41.3s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.3, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.5;, score=0.381 total time=  42.0s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=1e-05, reg_lambda=0, subsample=0.5;, score=0.458 total time= 1.9min
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.3, max_depth=9, min_child_weight=1, n_estimators=400, reg_alpha=1e-05, reg_lambda=0, subsample=0.5;, score=0.453 total time= 1.9min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1e-05, subsample=0.5;, score=0.244 total time=  37.2s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=200, reg_alpha=0, reg_lambda=1e-05, subsample=0.5;, score=0.241 total time=  36.8s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.7;, score=0.279 total time=  28.6s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=0, subsample=0.7;, score=0.276 total time=  28.1s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-05, subsample=1.0;, score=0.242 total time=  21.1s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=5, min_child_weight=7, n_estimators=100, reg_alpha=0.1, reg_lambda=1e-05, subsample=1.0;, score=0.243 total time=  17.6s
# [CV 1/2] END colsample_bytree=0.9, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=1.0;, score=0.300 total time=  47.7s
# [CV 2/2] END colsample_bytree=0.9, learning_rate=0.3, max_depth=3, min_child_weight=3, n_estimators=400, reg_alpha=0, reg_lambda=0, subsample=1.0;, score=0.304 total time=  47.4s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=0.9;, score=0.302 total time=  23.5s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=7, min_child_weight=1, n_estimators=100, reg_alpha=0, reg_lambda=0, subsample=0.9;, score=0.295 total time=  22.8s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.5;, score=0.289 total time=  47.4s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.5;, score=0.285 total time=  46.4s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=1e-05, subsample=1.0;, score=0.231 total time=  13.8s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.01, max_depth=3, min_child_weight=1, n_estimators=100, reg_alpha=0.01, reg_lambda=1e-05, subsample=1.0;, score=0.231 total time=  13.3s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.5;, score=0.298 total time=  46.7s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.05, max_depth=7, min_child_weight=5, n_estimators=200, reg_alpha=1e-05, reg_lambda=1e-05, subsample=0.5;, score=0.294 total time=  45.1s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.302 total time=  18.9s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.3, max_depth=5, min_child_weight=5, n_estimators=100, reg_alpha=0.01, reg_lambda=0.1, subsample=1.0;, score=0.302 total time=  18.4s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.01, subsample=0.5;, score=0.317 total time= 1.6min
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=7, min_child_weight=3, n_estimators=400, reg_alpha=0.1, reg_lambda=0.01, subsample=0.5;, score=0.314 total time= 1.4min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7;, score=0.274 total time=  54.9s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=5, min_child_weight=7, n_estimators=300, reg_alpha=0.1, reg_lambda=0.1, subsample=0.7;, score=0.273 total time=  52.5s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0, subsample=0.5;, score=0.350 total time= 1.4min
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.05, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=0, subsample=0.5;, score=0.343 total time= 1.5min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=0, reg_lambda=1e-05, subsample=1.0;, score=0.246 total time=  53.1s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=1, n_estimators=300, reg_alpha=0, reg_lambda=1e-05, subsample=1.0;, score=0.243 total time=  52.3s
# [CV 1/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0.01, reg_lambda=0.01, subsample=0.7;, score=0.286 total time=  35.3s
# [CV 2/2] END colsample_bytree=1.0, learning_rate=0.1, max_depth=5, min_child_weight=7, n_estimators=200, reg_alpha=0.01, reg_lambda=0.01, subsample=0.7;, score=0.289 total time=  37.0s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=1.0;, score=0.249 total time=  27.9s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=3, min_child_weight=1, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=1.0;, score=0.248 total time=  28.3s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.5;, score=0.250 total time=  47.0s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=7, min_child_weight=3, n_estimators=200, reg_alpha=0.1, reg_lambda=0.1, subsample=0.5;, score=0.247 total time=  51.6s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=7, n_estimators=200, reg_alpha=1e-05, reg_lambda=0.1, subsample=0.5;, score=0.306 total time=  55.6s
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.05, max_depth=9, min_child_weight=7, n_estimators=200, reg_alpha=1e-05, reg_lambda=0.1, subsample=0.5;, score=0.305 total time=  56.3s
# [CV 1/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1e-05, subsample=0.5;, score=0.267 total time= 1.5min
# [CV 2/2] END colsample_bytree=0.5, learning_rate=0.01, max_depth=9, min_child_weight=1, n_estimators=300, reg_alpha=0.1, reg_lambda=1e-05, subsample=0.5;, score=0.265 total time= 1.5min
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.9;, score=0.243 total time=  36.3s
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.01, max_depth=5, min_child_weight=3, n_estimators=200, reg_alpha=0.01, reg_lambda=1e-05, subsample=0.9;, score=0.241 total time=  39.9s
# [CV 1/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=7, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.7;, score=0.368 total time= 1.2min
# [CV 2/2] END colsample_bytree=0.7, learning_rate=0.1, max_depth=9, min_child_weight=7, n_estimators=200, reg_alpha=0.01, reg_lambda=0, subsample=0.7;, score=0.358 total time= 1.1min
# RandomizedSearchCV(cv=2,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            gamma=None, grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rate...
#                    param_distributions={'colsample_bytree': [0.5, 0.7, 0.9,
#                                                              1.0],
#                                         'learning_rate': [0.01, 0.05, 0.1, 0.3],
#                                         'max_depth': [3, 5, 7, 9],
#                                         'min_child_weight': [1, 3, 5, 7],
#                                         'n_estimators': [100, 200, 300, 400],
#                                         'reg_alpha': [0, 1e-05, 0.01, 0.1],
#                                         'reg_lambda': [0, 1e-05, 0.01, 0.1],
#                                         'subsample': [0.5, 0.7, 0.9, 1.0]},
#                    random_state=123,
#                    scoring=make_scorer(f1_score, response_method='predict', average=macro),
#                    verbose=3)

# %%
best_params = cv.best_params_
best_score = cv.best_score_

print("Best Parameters:", best_params)
print("Best Accuracy:", best_score)

# Evaluate the best model on the test set
best_model = cv.best_estimator_
y_pred = best_model.predict(X_test)
test_accuracy = precision_score(y_test, y_pred)
print("Test Accuracy:", test_accuracy)

# %%
best_model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.3, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None, num_class=4,
#               num_parallel_tree=None, ...)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.98      0.94    168214
#            1       0.67      0.36      0.47     22011
#            2       0.62      0.28      0.39      5142
#            3       0.76      0.26      0.38      1042
#
#     accuracy                           0.89    196409
#    macro avg       0.74      0.47      0.55    196409
# weighted avg       0.87      0.89      0.87    196409

# %%
pd.DataFrame({
    'names': X_train.columns,
    'importance': best_model.feature_importances_
}).sort_values('importance', ascending=False)
# Out:
#                                     names  importance
# 5                        cumsum_distances    0.023765
# 36                            yearday_sin    0.021692
# 75                        conditions_Snow    0.018933
# 77       conditions_Snow_Partially_cloudy    0.017651
# 78                   conditions_Snow_Rain    0.016608
# 34                         weekofyear_sin    0.016423
# 71                        conditions_Rain    0.016063
# 81  conditions_Snow_Rain_Partially_cloudy    0.015878
# 76               conditions_Snow_Overcast    0.015543
# 74       conditions_Rain_Partially_cloudy    0.015380
# 42                               hour_sin    0.015174
# 15                              snowdepth    0.014927
# 80          conditions_Snow_Rain_Overcast    0.014659
# 65        gestosc_zaludnienia_1km2_powiat    0.013569
# 59               switches_odometer_powiat    0.013479
# 73               conditions_Rain_Overcast    0.013270
# 39                           monthday_cos    0.013239
# 57               stations_odometer_powiat    0.012904
# 66                   preciptype_rain_snow    0.012810
# 37                            yearday_cos    0.012724
# 85                               icon_fog    0.012713
# 56                railway_distance_powiat    0.012606
# 35                         weekofyear_cos    0.012589
# 43                               hour_cos    0.012588
# 40                            weekday_sin    0.012329
# 12                                 precip    0.012329
# 58         level_crossing_odometer_powiat    0.012311
# 88                              icon_rain    0.012178
# 63                powierzchnia_km2_powiat    0.012166
# 23                            solarenergy    0.012122
# 48                   days_until_christmas    0.012121
# 8                                    temp    0.012078
# 89                              icon_snow    0.011956
# 83                       icon_clear-night    0.011944
# 7               nearest_big_city_distance    0.011941
# 1                               distances    0.011881
# 11                                    dew    0.011851
# 19                               pressure    0.011847
# 38                           monthday_sin    0.011807
# 32                              month_sin    0.011594
# 64                         ludnosc_powiat    0.011534
# 86                 icon_partly-cloudy-day    0.011368
# 26                     stop_duration_lag1    0.011364
# 9                               feelslike    0.011315
# 6                      distance_to_finish    0.011272
# 24                                uvindex    0.011219
# 33                              month_cos    0.011189
# 84                            icon_cloudy    0.011132
# 52                 railway_distance_gmina    0.010956
# 41                            weekday_cos    0.010878
# 0           station_count_on_curr_station    0.010865
# 22                         solarradiation    0.010819
# 18                                winddir    0.010801
# 62         gestosc_zaludnienia_1km2_gmina    0.010678
# 87               icon_partly-cloudy-night    0.010608
# 53                stations_odometer_gmina    0.010594
# 20                             visibility    0.010566
# 54          level_crossing_odometer_gmina    0.010537
# 61                          ludnosc_gmina    0.010477
# 60                 powierzchnia_km2_gmina    0.010461
# 21                             cloudcover    0.010417
# 27                     stop_duration_lag2    0.010408
# 25                          stop_duration    0.010382
# 10                               humidity    0.010341
# 17                              windspeed    0.010097
# 16                               windgust    0.010040
# 46                             second_sin    0.009971
# 29                     stop_duration_lag4    0.009918
# 55                switches_odometer_gmina    0.009669
# 14                                   snow    0.009653
# 28                     stop_duration_lag3    0.009458
# 70            conditions_Partially_cloudy    0.009429
# 67                        preciptype_snow    0.009267
# 2                               durations    0.009146
# 30                     stop_duration_lag5    0.009025
# 31                     stop_duration_lag6    0.008965
# 13                             precipprob    0.008941
# 69                    conditions_Overcast    0.008832
# 4                          switches_count    0.008698
# 68                         preciptype_nan    0.008659
# 3                    level_crossing_count    0.008512
# 45                             minute_cos    0.008081
# 44                             minute_sin    0.007994
# 47                             second_cos    0.007821
# 90                              icon_wind    0.000000
# 79               conditions_Snow_Rain_Fog    0.000000
# 82                         conditions_nan    0.000000
# 49               days_until_november_1_st    0.000000
# 50                days_until_new_year_eve    0.000000
# 51                      days_until_easter    0.000000
# 72                    conditions_Rain_Fog    0.000000
# 91                               icon_nan    0.000000

# %%
joblib.dump(best_model, 'models/multiclassifier0506_max_f1')
# Out:
# ['models/multiclassifier0506_max_f1']

# %%
xx=joblib.load('models/multiclassifier0506_max_f1')

# %%
xx
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=9, max_leaves=None,
#               min_child_weight=1, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=None, num_class=4,
#               num_parallel_tree=None, ...)

# %%
pred3 = model.predict(X_test)

# %%
print(classification_report(y_test, pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.93    168214
#            1       0.56      0.08      0.14     22011
#            2       0.51      0.10      0.16      5142
#            3       0.66      0.09      0.16      1042
#
#     accuracy                           0.86    196409
#    macro avg       0.65      0.32      0.35    196409
# weighted avg       0.83      0.86      0.82    196409
