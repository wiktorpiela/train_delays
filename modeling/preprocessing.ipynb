# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import utils.PreprocessingUtils as utils
from haversine import haversine, Unit

# %% [markdown]
# #### load data

# %%
data = pd.read_parquet('../data/raw_data_delays.parquet')
stations_gps = gpd.read_file('../data/spatial_data/stations_gps.shp', encoding='utf-8')

# %% [markdown]
# #### prepare raw data and join stations gps

# %%
data = utils.prepare_raw_data(data)
data = pd.merge(data, stations_gps, on='Stacja', how='left')

# %%
data = utils.geometry_point_to_lat_lon(data)

# %% [markdown]
# ### station count
# <ul>
#     <li>full route station count</li>
#     <li>station count on current station</li>
# </ul>

# %%
data['station_count_on_curr_station'] = data.groupby(['pk', 'Relacja']).cumcount()
# data['full_route_station_count'] = data.groupby(['pk', 'Relacja'])['Relacja'].transform('count')

# %% [markdown]
# #### get routes info

# %%
routes_data = pd.read_parquet('../data/routes_data_all.parquet').iloc[:,:8]

# %%
dfs_out = []
pks = data['pk'].unique()

for pk in pks:
    temp_df = data[data['pk']==pk].copy().reset_index(drop=True)

    key1 = temp_df.groupby('Relacja')['Stacja'].agg(utils.unique_list_preserve_order).index.item()
    key2 = ', '.join(temp_df.groupby('Relacja')['Stacja'].agg(utils.unique_list_preserve_order)[0])
    key = f'{key1}_{key2}'
    temp_df['key'] = key

    temp_df['prev_stations'] = temp_df['Stacja'].shift(1)
    temp_df['next_stations'] = temp_df['Stacja'].shift(-1)

    temp_df_merged = temp_df.merge(routes_data, how='left', on=['key','Relacja', 'Stacja', 'lat', 'lon', 'prev_stations', 'next_stations'])
    dfs_out.append(temp_df_merged)

df_out = pd.concat(dfs_out, ignore_index=True)

# %%
# checkpoint = df_out.copy()

# %%
keys_to_remove = df_out[df_out['distances'].isna()]['key'].unique()
df_out = df_out[~df_out['key'].isin(keys_to_remove)].reset_index(drop=True)

# %% [markdown]
# ### distances
# <ul>
#     <li>distance distance until current station</li>
#     <li>distance from start station</li>
#     <li>distance to final station</li>
#     <li>distance distance from the nearest big city station</li>
# </ul>

# %%
df_out['cumsum_distances'] = df_out.groupby('pk')['distances'].cumsum()

# %%
dfs_out = []
pks = df_out['pk'].unique()

for pk in pks:
    temp_df = df_out[df_out['pk']==pk].copy().reset_index(drop=True)
    temp_df['distance_to_finish'] = np.array(temp_df['cumsum_distances'].iloc[::-1])
    dfs_out.append(temp_df)
    
df_out = pd.concat(dfs_out, ignore_index=True)

# %%
big_city_names = pd.read_csv('../data/big_cities_dict.csv', sep=';').iloc[:,0].values
big_city_stations = stations_gps[stations_gps['Stacja'].isin(big_city_names)].reset_index(drop=True)
big_city_stations = utils.geometry_point_to_lat_lon(big_city_stations)

# %% [markdown]
# ### spatial data

# %%
data = utils.join_spatial_data(data, voivodeship_borders, county_borders, borough_borders)

# %% [markdown]
# ### date features and holidays

# %%
cols = ['arrival_on_time','departure_on_time']
for col in cols:
    data = utils.fix_dates(data, col)
    
data = utils.apply_date_features(data)
# Out:
# C:\Users\wpiel\web_dev\trains-delay-prediction\modeling\utils\PreprocessingUtils.py:85: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_temp[col_name] = new_dates

# %% [markdown]
# ### longer stop duration

# %%
data['stop_duration'] = (data['departure_on_time'] - data['arrival_on_time']).dt.total_seconds()/60
for i in range(1, 7):
    data[f'stop_duration_lag{i}'] = data.groupby(['pk','Relacja'])['stop_duration'].transform(lambda x: x.shift(i))
    data[f'stop_duration_lag{i}'] = data[f'stop_duration_lag{i}'].fillna(-1)

# %% [markdown]
# ### apply weather data

# %%
weather = pd.read_parquet('../data/weather_data.parquet')

# weather.drop(columns=['stations','source','tzoffset','datetimeEpoch'], inplace=True)
# weather['datetime_merge'] = pd.to_datetime(weather['date'].astype(str) + ' ' + weather['datetime'].astype(str))

# %%
data['datetime_merge'] = data['arrival_on_time'].dt.floor('H')
# Out:
# C:\Users\wpiel\AppData\Local\Temp\ipykernel_12712\39357879.py:1: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   data['datetime_merge'] = data['arrival_on_time'].dt.floor('H')

# %%
data = pd.merge(
    data,
    weather,
    how='left',
    on=['lat', 'lon', 'datetime_merge']
).drop(columns=['date','datetime_merge', 'datetime'])

# %% [markdown]
# ### fixing weather cols

# %% [markdown]
# #### snow, windgust, visibility, solarradiation, solarenergy, uvindex

# %%
cols_to_fix = ['snow','windgust','visibility','solarradiation','solarenergy','uvindex']
for col in cols_to_fix:
    data[col] = data[col].fillna(-1)

# %% [markdown]
# #### preciptype

# %%
data['preciptype'] = data['preciptype'].fillna('None')
data['preciptype'] = data['preciptype'].apply(lambda x: '_'.join(map(str, x)) if isinstance(x, np.ndarray) else x)
preciptype_dummies = pd.get_dummies(data['preciptype'], prefix='preciptype', dtype=float)
data = pd.concat([data.drop('preciptype', axis=1), preciptype_dummies], axis=1)

# %% [markdown]
# #### conditions

# %%
data['conditions'] = data['conditions'].str.replace(', ', '_').str.replace(',', '_').str.replace(' ', '_')
condition_dummies = pd.get_dummies(data['conditions'], dtype=float, prefix="conditions")
data = pd.concat([data.drop('conditions', axis=1), condition_dummies], axis=1)

# %% [markdown]
# #### icon

# %%
icon_dummies = pd.get_dummies(data['icon'], dtype=float, prefix="icon")
data = pd.concat([data.drop('icon', axis=1), icon_dummies], axis=1)

# %%
# data.to_parquet('../prepared_data_with_weather.parquet')

# %%
# data.to_parquet('../data/data_with_weather.parquet')

# %%
# data = pd.read_parquet('../data/data_with_weather.parquet')

# %%
# data.to_parquet('../data/prepared_data.parquet')

# %%
# data = pd.read_parquet('../data/prepared_data.parquet')

# %%
data['ML_TARGET'] = np.select(
    [
        data['Opóźnienie przyjazdu']<=5,
        (data['Opóźnienie przyjazdu']>5) & (data['Opóźnienie przyjazdu']<=20),
        (data['Opóźnienie przyjazdu']>20) & (data['Opóźnienie przyjazdu']<=60),
        data['Opóźnienie przyjazdu']>60
     ],
    [
        0,
        1,
        2,
        3 
    ]
)

# %%
near_city_names_dummies = pd.get_dummies(data['near_city_station_name'], prefix='near_city', dtype=float)
data = pd.concat([data.drop('near_city_station_name', axis=1), near_city_names_dummies], axis=1)

# %% [markdown]
# ### modeling

# %%
y = data['ML_TARGET']
X = data.iloc[:,9:].drop('ML_TARGET', axis=1)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from catboost import CatBoostClassifier
from sklearn.metrics import classification_report
# 739:	learn: 0.2732513	total: 17m 46s	remaining: 6m 14s
# 740:	learn: 0.2730359	total: 17m 48s	remaining: 6m 13s
# 741:	learn: 0.2729344	total: 17m 49s	remaining: 6m 11s
# 742:	learn: 0.2727489	total: 17m 51s	remaining: 6m 10s
# 743:	learn: 0.2726801	total: 17m 52s	remaining: 6m 9s
# 744:	learn: 0.2726155	total: 17m 53s	remaining: 6m 7s
# 745:	learn: 0.2725279	total: 17m 55s	remaining: 6m 6s
# 746:	learn: 0.2724558	total: 17m 56s	remaining: 6m 4s
# 747:	learn: 0.2722776	total: 17m 58s	remaining: 6m 3s
# 748:	learn: 0.2721548	total: 17m 59s	remaining: 6m 1s
# 749:	learn: 0.2719427	total: 18m 1s	remaining: 6m
# 750:	learn: 0.2717599	total: 18m 2s	remaining: 5m 58s
# 751:	learn: 0.2716777	total: 18m 4s	remaining: 5m 57s
# 752:	learn: 0.2716050	total: 18m 5s	remaining: 5m 56s
# 753:	learn: 0.2714659	total: 18m 6s	remaining: 5m 54s
# 754:	learn: 0.2713099	total: 18m 8s	remaining: 5m 53s
# 755:	learn: 0.2712049	total: 18m 9s	remaining: 5m 51s
# 756:	learn: 0.2711390	total: 18m 11s	remaining: 5m 50s
# 757:	learn: 0.2709193	total: 18m 12s	remaining: 5m 48s
# 758:	learn: 0.2708209	total: 18m 13s	remaining: 5m 47s
# 759:	learn: 0.2707162	total: 18m 15s	remaining: 5m 45s
# 760:	learn: 0.2706010	total: 18m 16s	remaining: 5m 44s
# 761:	learn: 0.2704901	total: 18m 18s	remaining: 5m 42s
# 762:	learn: 0.2704094	total: 18m 19s	remaining: 5m 41s
# 763:	learn: 0.2702059	total: 18m 20s	remaining: 5m 40s
# 764:	learn: 0.2700867	total: 18m 22s	remaining: 5m 38s
# 765:	learn: 0.2699486	total: 18m 23s	remaining: 5m 37s
# 766:	learn: 0.2698584	total: 18m 25s	remaining: 5m 35s
# 767:	learn: 0.2696286	total: 18m 26s	remaining: 5m 34s
# 768:	learn: 0.2695668	total: 18m 28s	remaining: 5m 32s
# 769:	learn: 0.2694841	total: 18m 30s	remaining: 5m 31s
# 770:	learn: 0.2693886	total: 18m 31s	remaining: 5m 30s
# 771:	learn: 0.2692196	total: 18m 33s	remaining: 5m 28s
# 772:	learn: 0.2691163	total: 18m 34s	remaining: 5m 27s
# 773:	learn: 0.2689866	total: 18m 36s	remaining: 5m 25s
# 774:	learn: 0.2688198	total: 18m 37s	remaining: 5m 24s
# 775:	learn: 0.2687679	total: 18m 38s	remaining: 5m 22s
# 776:	learn: 0.2687184	total: 18m 40s	remaining: 5m 21s
# 777:	learn: 0.2685702	total: 18m 41s	remaining: 5m 20s
# 778:	learn: 0.2684027	total: 18m 43s	remaining: 5m 18s
# 779:	learn: 0.2682321	total: 18m 44s	remaining: 5m 17s
# 780:	learn: 0.2681462	total: 18m 46s	remaining: 5m 15s
# 781:	learn: 0.2680109	total: 18m 47s	remaining: 5m 14s


# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94    193648
#            1       0.76      0.27      0.40     26044
#            2       0.78      0.35      0.48      6711
#            3       0.91      0.47      0.62      1241
#
#     accuracy                           0.89    227644
#    macro avg       0.84      0.52      0.61    227644
# weighted avg       0.88      0.89      0.86    227644

# %%
roc_auc_score(y_test, y_pred_proba, multi_class='ovr', average='macro')
# Out:
# 0.944761744795898

# %%
pd.DataFrame({
    'feature': X.columns,
    'importance': model.get_feature_importance()
}).sort_values('importance', ascending=False)
# Out:
#                                   feature    importance
# 1                full_route_station_count  1.104968e+01
# 15                         hour_angle_sin  9.001687e+00
# 6                     full_route_distance  8.080405e+00
# 39                               pressure  6.175209e+00
# 38                                winddir  4.401237e+00
# 4                     distance_from_start  3.939657e+00
# 17                     monthday_angle_sin  3.657513e+00
# 42                         solarradiation  3.438269e+00
# 16                      weekday_angle_sin  3.384708e+00
# 30                               humidity  3.053970e+00
# 41                             cloudcover  2.804621e+00
# 37                              windspeed  2.803795e+00
# 40                             visibility  2.633248e+00
# 36                               windgust  2.489090e+00
# 31                                    dew  2.465522e+00
# 7                    days_until_christmas  2.444738e+00
# 18                      yearday_angle_sin  2.300331e+00
# 5                       distance_to_final  2.270321e+00
# 2           distance_to_near_city_station  2.263290e+00
# 0           station_count_on_curr_station  1.904423e+00
# 28                                   temp  1.846472e+00
# 29                              feelslike  1.764282e+00
# 85               near_city_Wrocław Główny  1.081115e+00
# 3                distance_to_prev_station  1.074171e+00
# 77                     near_city_Katowice  1.047004e+00
# 35                              snowdepth  9.800189e-01
# 12                       weekday_Thursday  9.174583e-01
# 81                near_city_Poznań Główny  7.329424e-01
# 19                     weekyear_angle_sin  7.274386e-01
# 11                         weekday_Sunday  6.014816e-01
# 9                          weekday_Monday  5.897509e-01
# 21                          stop_duration  5.434759e-01
# 86                  near_city_Łódź Widzew  5.099131e-01
# 8                          weekday_Friday  4.693856e-01
# 75              near_city_Gdańsk Wrzeszcz  4.051258e-01
# 22                     stop_duration_lag1  3.788073e-01
# 83              near_city_Szczecin Główny  3.680678e-01
# 24                     stop_duration_lag3  3.474661e-01
# 73             near_city_Bydgoszcz Główna  3.463827e-01
# 23                     stop_duration_lag2  3.255106e-01
# 26                     stop_duration_lag5  2.986209e-01
# 25                     stop_duration_lag4  2.957769e-01
# 27                     stop_duration_lag6  2.916206e-01
# 13                        weekday_Tuesday  2.511055e-01
# 43                            solarenergy  2.319181e-01
# 82               near_city_Rzeszów Główny  2.278304e-01
# 44                                uvindex  2.244258e-01
# 50                    conditions_Overcast  2.156964e-01
# 67                 icon_partly-cloudy-day  2.087927e-01
# 68               icon_partly-cloudy-night  2.004465e-01
# 84           near_city_Warszawa Centralna  1.917058e-01
# 51            conditions_Partially_cloudy  1.900094e-01
# 79                near_city_Lublin Główny  1.599154e-01
# 78                    near_city_Kołobrzeg  1.561157e-01
# 20                        month_angle_sin  1.529419e-01
# 80               near_city_Olsztyn Główny  1.406619e-01
# 74          near_city_Częstochowa Stradom  1.381406e-01
# 72                    near_city_Białystok  1.226712e-01
# 32                                 precip  1.134812e-01
# 76                near_city_Gdynia Główna  8.753223e-02
# 14                      weekday_Wednesday  8.555444e-02
# 65                            icon_cloudy  6.484160e-02
# 46                        preciptype_rain  4.711494e-02
# 54               conditions_Rain_Overcast  4.668253e-02
# 10                       weekday_Saturday  3.120059e-02
# 49                       conditions_Clear  3.031139e-02
# 64                       icon_clear-night  2.697199e-02
# 34                                   snow  2.516952e-02
# 45                        preciptype_None  2.427618e-02
# 69                              icon_rain  2.001066e-02
# 63                         icon_clear-day  1.855993e-02
# 47                   preciptype_rain_snow  1.709211e-02
# 66                               icon_fog  1.234585e-02
# 61          conditions_Snow_Rain_Overcast  1.075655e-02
# 55       conditions_Rain_Partially_cloudy  6.845455e-03
# 70                              icon_snow  6.183508e-03
# 48                        preciptype_snow  4.527678e-03
# 58       conditions_Snow_Partially_cloudy  2.569146e-03
# 62  conditions_Snow_Rain_Partially_cloudy  7.584396e-04
# 52                        conditions_Rain  4.545178e-04
# 56                        conditions_Snow  2.008927e-04
# 57               conditions_Snow_Overcast  1.462196e-04
# 59                   conditions_Snow_Rain  3.006001e-05
# 60               conditions_Snow_Rain_Fog  3.322590e-06
# 53                    conditions_Rain_Fog  2.276756e-07
# 71                              icon_wind  0.000000e+00
# 33                             precipprob  0.000000e+00

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb = LabelBinarizer()
y_test_lb = y_test.fit_transform(y_test)
y_test = y_test.fit_transform(y_test)

# %%
y_test0 = np.where(y_test==0, 0, 1)
y_test1 = np.where(y_test==1, 1, 0)
y_test2 = np.where(y_test==2, 1, 0)
y_test3 = np.where(y_test==3, 1, 0)

fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba[0])
#
# File ~\web_dev\trains-delay-prediction\env\lib\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\web_dev\trains-delay-prediction\env\lib\site-packages\sklearn\metrics\_ranking.py:1095, in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     993 @validate_params(
#     994     {
#     995         "y_true": ["array-like"],
#    (...)
#    1004     y_true, y_score, *, pos_label=None, sample_weight=None, drop_intermediate=True
#    1005 ):
#    1006     """Compute Receiver operating characteristic (ROC).
#    1007
#    1008     Note: this implementation is restricted to the binary classification task.
#    (...)
#    1093     array([ inf, 0.8 , 0.4 , 0.35, 0.1 ])
#    1094     """
# -> 1095     fps, tps, thresholds = _binary_clf_curve(
#    1096         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#    1097     )
#    1099     # Attempt to drop thresholds corresponding to points in between and
#    1100     # collinear with other points. These are always suboptimal and do not
#    1101     # appear on a plotted ROC curve (and thus do not affect the AUC).
#    (...)
#    1106     # but does not drop more complicated cases like fps = [1, 3, 7],
#    1107     # tps = [1, 2, 4]; there is no harm in keeping too many thresholds.
#    1108     if drop_intermediate and len(fps) > 2:
#
# File ~\web_dev\trains-delay-prediction\env\lib\site-packages\sklearn\metrics\_ranking.py:804, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     802 y_type = type_of_target(y_true, input_name="y_true")
#     803 if not (y_type == "binary" or (y_type == "multiclass" and pos_label is not None)):
# --> 804     raise ValueError("{0} format is not supported".format(y_type))
#     806 check_consistent_length(y_true, y_score, sample_weight)
#     807 y_true = column_or_1d(y_true)
#
# ValueError: multiclass format is not supported

# %%
model.save_model('models/first_model')

# %% [markdown]
# ### weather features

# %%
data
# Out:
#             pk                                     Relacja  \
# 0            1                  Przeworsk - Rzeszów Główny
# 1            1                  Przeworsk - Rzeszów Główny
# 2            1                  Przeworsk - Rzeszów Główny
# 3            1                  Przeworsk - Rzeszów Główny
# 4            1                  Przeworsk - Rzeszów Główny
# ...        ...                                         ...
# 1138205  52128  Kraków Lotnisko - Wieliczka Rynek-Kopalnia
# 1138206  52128  Kraków Lotnisko - Wieliczka Rynek-Kopalnia
# 1138207  52128  Kraków Lotnisko - Wieliczka Rynek-Kopalnia
# 1138208  52128  Kraków Lotnisko - Wieliczka Rynek-Kopalnia
# 1138209  52128  Kraków Lotnisko - Wieliczka Rynek-Kopalnia
#
#                               Stacja  Opóźnienie przyjazdu  \
# 0                          Przeworsk                     0
# 1                            Grzęska                     0
# 2               Rogóżno koło Łańcuta                     0
# 3                             Kosina                     0
# 4                            Głuchów                     0
# ...                              ...                   ...
# 1138205              Kraków Bieżanów                     0
# 1138206  Kraków Bieżanów Drożdżownia                     0
# 1138207           Wieliczka Bogucice                     0
# 1138208               Wieliczka Park                     0
# 1138209     Wieliczka Rynek-Kopalnia                     0
#
#          Opóźnienie odjazdu     arrival_on_time   departure_on_time  \
# 0                         0 2022-12-01 06:55:00 2022-12-01 06:55:00
# 1                         0 2022-12-01 06:58:30 2022-12-01 06:59:00
# 2                         0 2022-12-01 07:03:00 2022-12-01 07:03:30
# 3                         0 2022-12-01 07:06:30 2022-12-01 07:07:00
# 4                         0 2022-12-01 07:09:30 2022-12-01 07:10:00
# ...                     ...                 ...                 ...
# 1138205                   0 2023-04-23 08:52:12 2023-04-23 08:52:42
# 1138206                   0 2023-04-23 08:55:00 2023-04-23 08:55:30
# 1138207                   0 2023-04-23 08:57:24 2023-04-23 08:57:54
# 1138208                   0 2023-04-23 09:00:06 2023-04-23 09:00:36
# 1138209                   0 2023-04-23 09:02:00 2023-04-23 09:02:00
#
#                lat        lon  station_count_on_curr_station  \
# 0        50.067161  22.503232                              0
# 1        50.080037  22.452564                              1
# 2        50.083573  22.362513                              2
# 3        50.083570  22.322846                              3
# 4        50.083469  22.279077                              4
# ...            ...        ...                            ...
# 1138205  50.021694  20.029257                             10
# 1138206  50.010696  20.035373                             11
# 1138207  49.998474  20.036696                             12
# 1138208  49.989105  20.049334                             13
# 1138209  49.985644  20.056648                             14
#
#          full_route_station_count  distance_to_near_city_station  \
# 0                              10                      35.612095
# 1                              10                      32.152599
# 2                              10                      25.854248
# 3                              10                      23.070959
# 4                              10                      20.013113
# ...                           ...                            ...
# 1138205                        15                      76.751356
# 1138206                        15                      77.593166
# 1138207                        15                      78.180632
# 1138208                        15                      79.411243
# 1138209                        15                      80.041721
#
#         near_city_station_name  distance_to_prev_station  distance_from_start  \
# 0               Rzeszów Główny                  0.000000             0.000000
# 1               Rzeszów Główny                  3.889077             3.889077
# 2               Rzeszów Główny                  6.437439            10.326516
# 3               Rzeszów Główny                  2.830260            13.156776
# 4               Rzeszów Główny                  3.122964            16.279739
# ...                        ...                       ...                  ...
# 1138205               Katowice                  2.235773            19.677470
# 1138206               Katowice                  1.298655            20.976125
# 1138207               Katowice                  1.362311            22.338436
# 1138208               Katowice                  1.378941            23.717377
# 1138209               Katowice                  0.649257            24.366635
#
#          distance_to_final  full_route_distance  stop_duration
# 0                36.484418            36.484418            0.0
# 1                31.639766            36.484418            0.5
# 2                28.265814            36.484418            0.5
# 3                22.842960            36.484418            0.5
# 4                20.043487            36.484418            0.5
# ...                    ...                  ...            ...
# 1138205           6.634256            24.366635            0.5
# 1138206           4.328076            24.366635            0.5
# 1138207           3.617016            24.366635            0.5
# 1138208           1.902019            24.366635            0.5
# 1138209           0.000000            24.366635            0.0
#
# [1138210 rows x 18 columns]

# %%
x = get_historical_weather(50.067161, 22.503232, '2022-12-01')

# %%
x
# Out:
# {'error': {'code': 2008, 'message': 'API key has been disabled.'}}
